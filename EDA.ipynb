# %% [markdown]
# # EDA

# %% [markdown]
# ## PASO 1: Importar las bibliotecas necesarias:

# %%
# !pip install streamlit
# !pip install pandas
# !pip install plotly
# !pip install yfinance

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import yfinance as yf

# %% [markdown]
# ## PASO 2: Obtener los datos históricos de las empresas desde el 01/01/1990:

# %%
start_date = pd.datetime.now().date() - pd.DateOffset(years=33)
end_date = pd.datetime.now().strftime('%Y-%m-%d')
end_date = pd.to_datetime(end_date).date()  # convertir a datetime.date
companies = ['AOS', 'AFL', 'ABT', 'PTC']

data = pd.DataFrame()
for company in companies:
    df = yf.download(company, start=start_date, end=end_date)
    df['Company'] = company
    data = pd.concat([data, df])
# Out:
# C:\Users\jorge\AppData\Local\Temp\ipykernel_9200\1893264761.py:1: FutureWarning: The pandas.datetime class is deprecated and will be removed from pandas in a future version. Import from datetime module instead.
#   start_date = pd.datetime.now().date() - pd.DateOffset(years=33)
# C:\Users\jorge\AppData\Local\Temp\ipykernel_9200\1893264761.py:2: FutureWarning: The pandas.datetime class is deprecated and will be removed from pandas in a future version. Import from datetime module instead.
#   end_date = pd.datetime.now().strftime('%Y-%m-%d')
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed

# %% [markdown]
# ## PASO 3: Visualizar el conjunto de datos y explorar sus estadísticas descriptivas:

# %%
print(data.head())
print(data.describe())
# Out:
#                 Open      High       Low     Close  Adj Close  Volume Company
# Date
# 1990-03-28  0.861111  0.861111  0.861111  0.861111   0.433764   18000     AOS
# 1990-03-29  0.861111  0.861111  0.861111  0.861111   0.433764   21600     AOS
# 1990-03-30  0.861111  0.881944  0.861111  0.875000   0.440760   34200     AOS
# 1990-04-02  0.868056  0.868056  0.861111  0.868056   0.437262   30600     AOS
# 1990-04-03  0.861111  0.861111  0.819444  0.833333   0.419772  219600     AOS
#                Open          High           Low         Close     Adj Close  \
# count  33252.000000  33252.000000  33252.000000  33252.000000  33252.000000
# mean      27.914792     28.268080     27.544632     27.916272     25.006980
# std       27.285495     27.602565     26.944777     27.280017     27.446940
# min        0.756944      0.756944      0.750000      0.750000      0.386571
# 25%        6.957964      7.064375      6.849583      6.957964      4.936043
# ...

# %%
data['Date'] = data.index.date
data = data[(data['Date'] >= start_date) & (data['Date'] <= end_date)]
# Out:
# C:\Users\jorge\AppData\Local\Temp\ipykernel_9200\2165975343.py:2: FutureWarning: Comparison of Timestamp with datetime.date is deprecated in order to match the standard library behavior. In a future version these will be considered non-comparable. Use 'ts == pd.Timestamp(date)' or 'ts.date() == date' instead.
#   data = data[(data['Date'] >= start_date) & (data['Date'] <= end_date)]

# %% [markdown]
# ## PASO 4: Visualizar la distribución de las variables numéricas:

# %% [markdown]
# date debe ser x y Close y

# %%
sns.lineplot(data=data, x='Date', y='Close', hue='Company')
plt.xlabel('Fechas históricas de los últimos 33 años')
plt.ylabel('Precio de cierre')
plt.title('Distribución del precio de cierre por empresa')
plt.show()

# %% [markdown]
# ## PASO 5: Realizar un análisis bivariado de las variables numéricas y/o categóricas:

# %%
sns.pairplot(data=data, hue='Company')
plt.show()

# %% [markdown]
# ## PASO 6: Identificar patrones, outliers y/o anomalías en los datos:

# %%
sns.boxplot(data=data, x='Company', y='Close')
plt.xlabel('Empresa')
plt.ylabel('Precio de cierre')
plt.title('Boxplot del precio de cierre por empresa')
plt.show()

sns.boxplot(data=data, x='Company', y='Volume')
plt.xlabel('Empresa')
plt.ylabel('Volumen')
plt.title('Boxplot del volumen por empresa')
plt.show()

# %% [markdown]
# ----------------------------

# %% [markdown]
# --------------------------
